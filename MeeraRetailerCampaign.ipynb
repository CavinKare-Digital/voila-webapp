# %% [markdown]
# # Meera Retailer Campaign - Random Pick

# %% [markdown]
# ## Objective
# * Choose random retailers satisfying certain criteria providing weights based on the purchasing ability of retailers
# * Choose the number of random retailers based on the weightage of number of retailers under each AM

# %% [markdown]
# ## Steps

# %% [markdown]
# 1. Import packages
# 2. Import data
# 3. Remove null
# 4. Occurence of Retailer
# 5. Weightage for AM
# 6. Split data based on AM's
# 7. Function to generate random Rtr's with AM weightage

# %% [markdown]
# ### Import packages

# %%
from ckpackages import azsql 
import numpy as np
import pandas as pd
import random

# %% [markdown]
# ### Import data

# %%
Query = 'select * from v_PC_MeeraRetailerCampaign' 
#RSC Transactions for Meera Powder
data = azsql.callstatement(Query)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 766 entries, 0 to 765
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   RtrCode         766 non-null    object
#  1   RtrName         766 non-null    object
#  2   RtrGroupCde     761 non-null    object
#  3   DistName        766 non-null    object
#  4   BillNo          766 non-null    object
#  5   InvDate         766 non-null    datetime64[ns]
#  6   Brand           766 non-null    object
#  7   PrdName         766 non-null    object
#  8   StateName       0 non-null      object
#  9   ZM              766 non-null    object
#  10  AMName          766 non-null    object
#  11  TSOName         766 non-null    object
#  12  TotalQty        766 non-null    float64
#  13  PolypouchCount  766 non-null    float64
#  14  FinYr           766 non-null    object
#  15  JC              766 non-null    object
#  16  JCWk            766 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(14)
# memory usage: 101.9+ KB

# %%
data.head()
# Out:
#                                      RtrCode               RtrName  \
# 0                  TNLUM001-SLM0011553239845            JR MALIGAI
# 1  GT0100020067820002006782-SLM0011562060211           M.AHAMED&CO
# 2                        S100000941550670081  Sundha general store
# 3  GT0100020001540002000154-SLM0011556707922     sri suntha agency
# 4  GT0100020000770002000077-SLM0011560947175            mansarovar
#
#                 RtrGroupCde              DistName        BillNo    InvDate  \
# 0  PC-KIRANA/GENERAL STORES        STAR MARKETING  CKBIL2005953 2020-09-30
# 1  PC-KIRANA/GENERAL STORES    SRI CHANDRA STORES  CKBIL2000222 2020-09-30
# 2  PC-KIRANA/GENERAL STORES          JAI AGENCIES  CKBIL2001933 2020-09-30
# 3              PC-WHOLESALE       ESWARI AGENCIES  CKBIL2001633 2020-10-04
# 4              PC-WHOLESALE  ARIHANT DISTRIBUTORS  CKBIL2000405 2020-09-30
#
#                   Brand                                   PrdName StateName  \
# 0  Meera Powder & Paste   MEERA ADVANCE HW POWDER 5.6 GM 1350 PCS      None
# 1  Meera Powder & Paste   MEERA ADVANCE HW POWDER 5.6 GM 1350 PCS      None
# 2  Meera Powder & Paste   MEERA ADVANCE HW POWDER 5.6 GM 1350 PCS      None
# 3  Meera Powder & Paste   MEERA ADVANCE HW POWDER 5.6 GM 1350 PCS      None
# 4  Meera Powder & Paste  MEERA ADVANCE HW POWDER 40GM REFILL 100P      None
#
#           ZM        AMName          TSOName  TotalQty  PolypouchCount  \
# 0  C PERUMAL  SYED IBRAHIM      R JAIGANESH     150.0        1.000000
# 1  C PERUMAL  SYED IBRAHIM  ELANGO VELUSAMY    2700.0       18.000000
# 2  C PERUMAL      BALAJI S  IMMANUEL RAJA J    1350.0        9.000000
# 3  C PERUMAL  SYED IBRAHIM      R JAIGANESH     150.0        1.000000
# 4  C PERUMAL      BALAJI S           R RAJA     500.0        3.333333
#
#      FinYr    JC  JCWk
# 0  2020-21  JC07  WK02
# 1  2020-21  JC07  WK02
# 2  2020-21  JC07  WK02
# 3  2020-21  JC07  WK03
# 4  2020-21  JC07  WK02

# %%
# Data only for Latest date
data = data[data['InvDate'] == data['InvDate'].max()]

# %% [markdown]
# ### Remove null

# %%
# Retailers without AM
print(data['AMName'].isnull().sum())
data[data['AMName'].isnull()]
# Out:
# 0
# Empty DataFrame
# Columns: [RtrCode, RtrName, RtrGroupCde, DistName, BillNo, InvDate, Brand, PrdName, StateName, ZM, AMName, TSOName, TotalQty, PolypouchCount, FinYr, JC, JCWk]
# Index: []

# %%
# Consider Data with AMName ( remove nulls)
data = data[data['AMName'].notnull()]

# %% [markdown]
# ### Occurence of Retailer

# %%
# List of retailer
rt = data['RtrCode'].tolist()
rt.sort()
rtr = pd.Series(rt).value_counts()
rtr_list = pd.DataFrame(rtr,columns = ['retailer'] )
rtr_list['retailer']
# Out:
# TNJTR006-SLM0021552892243                     1
# S100000701550583816                           1
# S100000601551088512                           1
# S100000351550925744                           1
# TNNAA003-SLM0011553499862                     1
#                                              ..
# GT0100020035390002003539-SLM00231574664081    1
# S100000161563351070                           1
# TNNAA003-SLM0011553515191                     1
# S100000021550647196                           1
# S100000211564988007                           1
# Name: retailer, Length: 143, dtype: int64

# %%
# Maximum occurence of retailer
rtr_list['retailer'].max()
# Out:
# 1

# %%
rtr_master = data[['RtrCode','RtrName','DistName','RtrGroupCde','InvDate','PolypouchCount']].drop_duplicates()

# %%
rtr_master['PolypouchCount'] = rtr_master['PolypouchCount'].astype(int)

# %%
# Choose number of retailers to choose
pick = 45

# %% [markdown]
# ### Weightage for AM

# %%
# Percentage of Retailers across AM-Wise
TotalRtrCount = data['RtrCode'].count()
AM_RTR_WGT = data.groupby('AMName')['RtrCode'].count().reset_index()
AM_RTR_WGT['WGT%'] = np.ceil((AM_RTR_WGT['RtrCode']/TotalRtrCount) * pick)

# %%
TotalRtrCount
# Out:
# 143

# %%
AM_RTR_WGT
# Out:
#          AMName  RtrCode  WGT%
# 0      BALAJI S       83  27.0
# 1     SAFIULLAH       29  10.0
# 2  SYED IBRAHIM       27   9.0
# 3    V BHARATHI        4   2.0

# %% [markdown]
# ### Split dataframe on AM's

# %%
# Select required rows
data1 = data[['ZM','AMName','RtrCode','RtrName','TotalQty','PolypouchCount']]

# %%
data2 = [rows for _, rows in data1.groupby('AMName')]
#data2 = [{gender: rows for gender, rows in data1.groupby('AMName')}]

# %%
data2[0]
# Out:
#             ZM    AMName              RtrCode               RtrName  TotalQty  \
# 109  C PERUMAL  BALAJI S  S100000361552893510          Ganesh store     150.0
# 137  C PERUMAL  BALAJI S  S100000361552897824        D. K. P stores     150.0
# 164  C PERUMAL  BALAJI S  S100000361552900061  Mariyappan Wholesale     150.0
# 189  C PERUMAL  BALAJI S  S100000361552900907      Lakshmi MALLIGAI     150.0
# 198  C PERUMAL  BALAJI S  S100000481551172555        SARAVANA STORE     150.0
# ..         ...       ...                  ...                   ...       ...
# 750  C PERUMAL  BALAJI S  S100000431551682220          MADHAN STORE     150.0
# 752  C PERUMAL  BALAJI S  S100000431551687714           ANNAI STORE     450.0
# 754  C PERUMAL  BALAJI S  S100000461551077596       SRI ARUNA STORE     150.0
# 756  C PERUMAL  BALAJI S  S100000461551085711      SRI SAIRAM STORE     150.0
# 758  C PERUMAL  BALAJI S  S100000461551087198     JAYAMURUGAN STORE    1350.0
#
#      PolypouchCount
# 109             1.0
# 137             1.0
# 164             1.0
# 189             1.0
# 198             1.0
# ..              ...
# 750             1.0
# 752             3.0
# 754             1.0
# 756             1.0
# 758             9.0
#
# [83 rows x 6 columns]

# %%
data2[1]
# Out:
#             ZM     AMName                                     RtrCode  \
# 70   C PERUMAL  SAFIULLAH                         S100000661550836269
# 163  C PERUMAL  SAFIULLAH  GT0100020035390002003539-SLM00231574664081
# 178  C PERUMAL  SAFIULLAH                   TNSKT006-SLM0011552110564
# 188  C PERUMAL  SAFIULLAH  GT0100020035390002003539-SLM00241597645899
# 201  C PERUMAL  SAFIULLAH                   TNSKT006-SLM0011552288132
# 207  C PERUMAL  SAFIULLAH                   TNJTR006-SLM0011552299052
# 210  C PERUMAL  SAFIULLAH                         S100000581597045306
# 222  C PERUMAL  SAFIULLAH                   TNSKT006-SLM0011552297540
# 226  C PERUMAL  SAFIULLAH   GT0100020001120002000112-SLM0021572506614
# 228  C PERUMAL  SAFIULLAH                   TNJTR006-SLM0021552891497
# 231  C PERUMAL  SAFIULLAH                         S100000581597047799
# 243  C PERUMAL  SAFIULLAH                   TNSKT006-SLM0011552900776
# 247  C PERUMAL  SAFIULLAH                   TNJTR006-SLM0021552892243
# 250  C PERUMAL  SAFIULLAH                         S100000591551162332
# 265  C PERUMAL  SAFIULLAH                   TNJTR006-SLM0031552894595
# 268  C PERUMAL  SAFIULLAH                         S100000591551164600
# 286  C PERUMAL  SAFIULLAH                         S100000591551166703
# 302  C PERUMAL  SAFIULLAH                         S100000591551167915
# 318  C PERUMAL  SAFIULLAH                         S100000591551169817
# 332  C PERUMAL  SAFIULLAH                         S100000591551683075
# 345  C PERUMAL  SAFIULLAH                         S100000591551688085
# 357  C PERUMAL  SAFIULLAH                         S100000591551690729
# 369  C PERUMAL  SAFIULLAH                         S100000591551691834
# 381  C PERUMAL  SAFIULLAH                         S100000591552984465
# 392  C PERUMAL  SAFIULLAH                         S100000601551088512
# 403  C PERUMAL  SAFIULLAH                         S100000601551682244
# 414  C PERUMAL  SAFIULLAH                         S100000701550583816
# 425  C PERUMAL  SAFIULLAH                         S100000701552040542
# 658  C PERUMAL  SAFIULLAH                   TNGRP001-SLM0011552804118
#
#                      RtrName  TotalQty  PolypouchCount
# 70             SANJAY STORES    1350.0             9.0
# 163    SUYAMBU LINGAM SOTORE     750.0             5.0
# 178        L.R.MUNIR TRADERS     150.0             1.0
# 188                A.N STORE     150.0             1.0
# 201      H.R.S.MALIGAI STORE     150.0             1.0
# 207         NEW NELLAI STORR     150.0             1.0
# 210                 Kr store     150.0             1.0
# 222     SAKTHI MALIGAI STORE     300.0             2.0
# 226         NAT JI MARKETING    1350.0             9.0
# 228      Pasumai supermarket     150.0             1.0
# 231              D.S MALIGAI     150.0             1.0
# 243  SRI JAYAM MALIGAI STORE     150.0             1.0
# 247     PASUMI SUPER MARKET      300.0             2.0
# 250               Stmmaligai     150.0             1.0
# 265  ERODE MALIGAI AGENCIES      150.0             1.0
# 268              Sakthistore     150.0             1.0
# 286            Parvathistore     150.0             1.0
# 302                    Raja3     150.0             1.0
# 318       Srivigneswarastore     150.0             1.0
# 332      ThangarathinAmstore     150.0             1.0
# 345   Srisomasundarapharmacy     150.0             1.0
# 357        D.r.blessingstore     150.0             1.0
# 369               Prabustore     150.0             1.0
# 381              Matha store     150.0             1.0
# 392             Iruthay meri     150.0             1.0
# 403         Ashirvadam Store     150.0             1.0
# 414           Welcome stores     300.0             2.0
# 425            Anitha stores    1350.0             9.0
# 658            MURUGAN STORE     150.0             1.0

# %%
data2[2]
# Out:
#             ZM        AMName                                     RtrCode  \
# 5    C PERUMAL  SYED IBRAHIM                   TNPKS002-SLM0011553581012
# 55   C PERUMAL  SYED IBRAHIM   GT0100020001530002000153-SLM0011560406478
# 71   C PERUMAL  SYED IBRAHIM   GT0100020001600002000160-SLM0011557395203
# 89   C PERUMAL  SYED IBRAHIM   GT0100020001530002000153-SLM0011560410051
# 166  C PERUMAL  SYED IBRAHIM   GT0100020001660002000166-SLM0021575878510
# 168  C PERUMAL  SYED IBRAHIM   GT0100020001400002000140-SLM0011559211800
# 191  C PERUMAL  SYED IBRAHIM  GT0100020066330002006633-SLM00141583145700
# 271  C PERUMAL  SYED IBRAHIM   GT0100020001390002000139-SLM0021555310420
# 315  C PERUMAL  SYED IBRAHIM   GT0100020001590002000159-SLM0021596182268
# 317  C PERUMAL  SYED IBRAHIM   GT0100020001560002000156-SLM0021568360558
# 326  C PERUMAL  SYED IBRAHIM   GT0100020001580002000158-SLM0011596877429
# 330  C PERUMAL  SYED IBRAHIM                   TNNVA003-SLM0011553325141
# 333  C PERUMAL  SYED IBRAHIM   GT0100020001730002000173-SLM0011596540353
# 340  C PERUMAL  SYED IBRAHIM                   TNNAA003-SLM0011552716555
# 352  C PERUMAL  SYED IBRAHIM                   TNNAA003-SLM0011553242776
# 364  C PERUMAL  SYED IBRAHIM                   TNNAA003-SLM0011553499862
# 376  C PERUMAL  SYED IBRAHIM                   TNNAA003-SLM0011553515191
# 383  C PERUMAL  SYED IBRAHIM   GT0100020001680002000168-SLM0071598866569
# 394  C PERUMAL  SYED IBRAHIM   GT0100020001780002000178-SLM0061562306520
# 405  C PERUMAL  SYED IBRAHIM   GT0100020001780002000178-SLM0061562306730
# 416  C PERUMAL  SYED IBRAHIM   GT0100020001780002000178-SLM0061562310033
# 427  C PERUMAL  SYED IBRAHIM   GT0100020001780002000178-SLM0061562315032
# 566  C PERUMAL  SYED IBRAHIM   GT0100020001780002000178-SLM0041554711729
# 574  C PERUMAL  SYED IBRAHIM   GT0100020001780002000178-SLM0041555320924
# 582  C PERUMAL  SYED IBRAHIM   GT0100020001780002000178-SLM0041557132553
# 589  C PERUMAL  SYED IBRAHIM   GT0100020001780002000178-SLM0081555305734
# 749  C PERUMAL  SYED IBRAHIM   GT0100020001640002000164-SLM0011573026022
#
#                                  RtrName  TotalQty  PolypouchCount
# 5                         ARUNA AGENCIES    2700.0            18.0
# 55                       BILLAL MALIGAI      150.0             1.0
# 71                   VICHUNADU  MALIGAI      150.0             1.0
# 89                   SEENI MUHAMAD STORE     150.0             1.0
# 166                  Sree laxmee traders     150.0             1.0
# 168  SRI THIRUMURUGAN DEPARTMENTAL STORE     150.0             1.0
# 191                   New selvam maligai     150.0             1.0
# 271                         RAMATH STORE     150.0             1.0
# 315             SRI KRISHNA SUPER MARKET    1350.0             9.0
# 317              KURINJI SHOPPING CENTRE     150.0             1.0
# 326                 SRI THIRUPATHI STORE     150.0             1.0
# 330                      LAKSHMI BANGLES    1350.0             9.0
# 333                Anjanya Vethal Store      150.0             1.0
# 340                       ARASAN MALIGAI     300.0             2.0
# 352              SINGAPORE SHOPPING MALL     150.0             1.0
# 364                        KANMANI STORE     150.0             1.0
# 376      MANGALAM & CO  GENERAL MERCHANT     300.0             2.0
# 383                        The home park     150.0             1.0
# 394                MARIKANNAN MINI STORE     150.0             1.0
# 405                         Selvam store     150.0             1.0
# 416                      ARUNSUNAI STORE     150.0             1.0
# 427                        DHIVYAM STORE     150.0             1.0
# 566                  APPLE SHOPPING MALL    2700.0            18.0
# 574                        GANESH STORE      300.0             2.0
# 582                      AMIRTHAA STORE      150.0             1.0
# 589                    SRI LAKSHMI STORE     300.0             2.0
# 749                      S.R VETRI STORE    1350.0             9.0

# %%
data2[3]
# Out:
#             ZM      AMName                                    RtrCode  \
# 197  C PERUMAL  V BHARATHI  GT0100020000890002000089-SLM0011559377878
# 274  C PERUMAL  V BHARATHI                        S100000971551077797
# 291  C PERUMAL  V BHARATHI                        S100000971560412599
# 307  C PERUMAL  V BHARATHI                        S100000971597394200
#
#              RtrName  TotalQty  PolypouchCount
# 197  m.h yosuf store   19387.0      129.246667
# 274    Ramu maligai      150.0        1.000000
# 291     vishnu store     150.0        1.000000
# 307  N.K Sekar store     150.0        1.000000

# %% [markdown]
# ### Function to generate random Rtr's with AM weightage

# %% [markdown]
# ### Case 1: With repetitions (allowing 1st two instances of duplicates)

# %%
def randomRtrAmWise(i):
    # Retailer name
    a = data2[i]['RtrCode'].tolist()

    # Polypouch count as weight
    ppc = data2[i]['PolypouchCount'].tolist() 

    c=int(AM_RTR_WGT['WGT%'][i])
#    random.shuffle(a)
    l = random.choices(a, weights=ppc, k=c)
    l.sort()
    df_R = pd.DataFrame(l,columns = ['RtrCode'])
    df_R['AMName'] = AM_RTR_WGT['AMName'][i]
    return df_R
    
def randompick():
    df_RtrRP = pd.DataFrame()
    for j in range(len( AM_RTR_WGT.index.tolist())):
        df = randomRtrAmWise(j)
        df_RtrRP = df_RtrRP.append(df)
    return df_RtrRP

def randompickAM():
    result = randompick()
    result = result.merge(rtr_master,on='RtrCode')
    result = result.groupby('RtrCode').head(2).reset_index(drop=True) # Keep 1st two instances of duplicates
    index = result.index
    number_of_rows = len(index)
    print('Count of picked retailers: ',number_of_rows)
    result.to_csv('results_05102020.csv')
    return result
""""    if (number_of_rows==pick):
        print('Selected')
        return(result)
    else:
        print('Try again')"""
# Out:
# '"    if (number_of_rows==pick):\n        print(\'Selected\')\n        return(result)\n    else:\n        print(\'Try again\')'

# %%
randompickAM()
# Out:
# Count of picked retailers:  43
#                                       RtrCode        AMName  \
# 0   GT0100020035380002003538-SLM0031558935467      BALAJI S
# 1   GT0100020035380002003538-SLM0031558935467      BALAJI S
# 2                         S100000021550649387      BALAJI S
# 3                         S100000041550905617      BALAJI S
# 4                         S100000101550488382      BALAJI S
# 5                         S100000141550476321      BALAJI S
# 6                         S100000151551252740      BALAJI S
# 7                         S100000161563351070      BALAJI S
# 8                         S100000191551091753      BALAJI S
# 9                         S100000191551091753      BALAJI S
# 10                        S100000211550467111      BALAJI S
# 11                        S100000221550487587      BALAJI S
# 12                        S100000221550487587      BALAJI S
# 13                        S100000381550906040      BALAJI S
# 14                        S100000401550734471      BALAJI S
# 15                        S100000431551075601      BALAJI S
# 16                        S100000491558336016      BALAJI S
# 17                        S100000931551077855      BALAJI S
# 18                        S100000931551081127      BALAJI S
# 19                        S100000931551679536      BALAJI S
# 20                  TNSSR009-SLM0011550908876      BALAJI S
# 21                  TNSSR009-SLM0011550908876      BALAJI S
# 22  GT0100020001120002000112-SLM0021572506614     SAFIULLAH
# 23                        S100000591551164600     SAFIULLAH
# 24                        S100000591551169817     SAFIULLAH
# 25                        S100000591551683075     SAFIULLAH
# 26                        S100000661550836269     SAFIULLAH
# 27                        S100000661550836269     SAFIULLAH
# 28                  TNJTR006-SLM0011552299052     SAFIULLAH
# 29                  TNSKT006-SLM0011552297540     SAFIULLAH
# 30                  TNSKT006-SLM0011552297540     SAFIULLAH
# 31                  TNSKT006-SLM0011552900776     SAFIULLAH
# 32  GT0100020001590002000159-SLM0021596182268  SYED IBRAHIM
# 33  GT0100020001640002000164-SLM0011573026022  SYED IBRAHIM
# 34  GT0100020001780002000178-SLM0041554711729  SYED IBRAHIM
# 35  GT0100020001780002000178-SLM0041554711729  SYED IBRAHIM
# 36  GT0100020001780002000178-SLM0061562310033  SYED IBRAHIM
# 37                  TNNAA003-SLM0011552716555  SYED IBRAHIM
# 38                  TNNAA003-SLM0011553499862  SYED IBRAHIM
# 39                  TNNVA003-SLM0011553325141  SYED IBRAHIM
# 40                  TNPKS002-SLM0011553581012  SYED IBRAHIM
# 41  GT0100020000890002000089-SLM0011559377878    V BHARATHI
# 42  GT0100020000890002000089-SLM0011559377878    V BHARATHI
#
#                         RtrName                       DistName  \
# 0            JAIBAIRAVI TRADERS          EVERGREEN ENTERPRISES
# 1            JAIBAIRAVI TRADERS          EVERGREEN ENTERPRISES
# 2                     CPS STORE                     PONNI & CO
# 3                AKSHYA TRADERS                     PONNI & CO
# 4                RATHANA STORES                TP DISTRIBUTION
# 5                    RAJA STORE         SUN AGRO-COM RESOURCES
# 6                   R.C.TRADERS                     PONNI & CO
# 7         SRI THIRUPTHI TRADERS                     PONNI & CO
# 8                  G.v traders           EVERGREEN ENTERPRISES
# 9                  G.v traders           EVERGREEN ENTERPRISES
# 10        NEW SELVAKUMAR STORE           EVERGREEN ENTERPRISES
# 11             ISHWARYA  STORE             HARISH KANNA AGENCY
# 12             ISHWARYA  STORE             HARISH KANNA AGENCY
# 13                   RAJU STORE                 SUDHA AGENCIES
# 14               National Store                TP DISTRIBUTION
# 15               ARAVIND STORE           EVERGREEN ENTERPRISES
# 16         A  B C Food products                   T.L AGENCIES
# 17                GREEN BAZAAR                      K L GROUPS
# 18             SAIYED ARABHADH                      K L GROUPS
# 19                MATHINA STORE                     K L GROUPS
# 20  Murugan Stores Super Market                     PONNI & CO
# 21  Murugan Stores Super Market                     PONNI & CO
# 22             NAT JI MARKETING               K R DISTRIBUTORS
# 23                  Sakthistore  SRI UKKRAKALIAMMAN MARKETTING
# 24           Srivigneswarastore  SRI UKKRAKALIAMMAN MARKETTING
# 25          ThangarathinAmstore  SRI UKKRAKALIAMMAN MARKETTING
# 26                SANJAY STORES            M.S.SUNDARAM STORES
# 27                SANJAY STORES            M.S.SUNDARAM STORES
# 28             NEW NELLAI STORR                  JAYAM TRADERS
# 29         SAKTHI MALIGAI STORE         SHRI KEERTHANA TRADERS
# 30         SAKTHI MALIGAI STORE         SHRI KEERTHANA TRADERS
# 31      SRI JAYAM MALIGAI STORE         SHRI KEERTHANA TRADERS
# 32     SRI KRISHNA SUPER MARKET                   NILA VANIGAM
# 33              S.R VETRI STORE                SELVAA AGENCIES
# 34          APPLE SHOPPING MALL          VISALAKSHI MARKETINGS
# 35          APPLE SHOPPING MALL          VISALAKSHI MARKETINGS
# 36              ARUNSUNAI STORE           SAI SRI SARAN AGENCY
# 37               ARASAN MALIGAI         NEW AKILADEVI AGENCIES
# 38                KANMANI STORE         NEW AKILADEVI AGENCIES
# 39              LAKSHMI BANGLES                   NILA VANIGAM
# 40               ARUNA AGENCIES     PKS JEYARAJ NADAR&BROTHERS
# 41              m.h yosuf store         SRI MAHESWARI AGENCIES
# 42              m.h yosuf store         SRI MAHESWARI AGENCIES
#
#                                         RtrGroupCde    InvDate  PolypouchCount
# 0                          PC-KIRANA/GENERAL STORES 2020-10-05               9
# 1                          PC-KIRANA/GENERAL STORES 2020-10-05               9
# 2                                      PC-WHOLESALE 2020-10-05               2
# 3                                      PC-WHOLESALE 2020-10-05              45
# 4                                      PC-WHOLESALE 2020-10-05               9
# 5                          PC-KIRANA/GENERAL STORES 2020-10-05               1
# 6                                      PC-WHOLESALE 2020-10-05              18
# 7                                      PC-WHOLESALE 2020-10-05               9
# 8                                      PC-WHOLESALE 2020-10-05              90
# 9                                      PC-WHOLESALE 2020-10-05              90
# 10                                     PC-WHOLESALE 2020-10-05               9
# 11                                     PC-WHOLESALE 2020-10-05               9
# 12                                     PC-WHOLESALE 2020-10-05               9
# 13                                     PC-WHOLESALE 2020-10-05               2
# 14                                     PC-WHOLESALE 2020-10-05               9
# 15                         PC-KIRANA/GENERAL STORES 2020-10-05               1
# 16                         PC-KIRANA/GENERAL STORES 2020-10-05               2
# 17  PC-Super Market (MT in GT & Departmental Store) 2020-10-05               9
# 18                         PC-KIRANA/GENERAL STORES 2020-10-05              27
# 19                                     PC-WHOLESALE 2020-10-05               9
# 20  PC-Super Market (MT in GT & Departmental Store) 2020-10-05              18
# 21  PC-Super Market (MT in GT & Departmental Store) 2020-10-05              18
# 22                                     PC-WHOLESALE 2020-10-05               9
# 23                         PC-KIRANA/GENERAL STORES 2020-10-05               1
# 24                         PC-KIRANA/GENERAL STORES 2020-10-05               1
# 25                         PC-KIRANA/GENERAL STORES 2020-10-05               1
# 26                                     PC-WHOLESALE 2020-10-05               9
# 27                                     PC-WHOLESALE 2020-10-05               9
# 28                         PC-KIRANA/GENERAL STORES 2020-10-05               1
# 29  PC-Super Market (MT in GT & Departmental Store) 2020-10-05               2
# 30  PC-Super Market (MT in GT & Departmental Store) 2020-10-05               2
# 31                         PC-KIRANA/GENERAL STORES 2020-10-05               1
# 32                                           PC-PAN 2020-10-05               9
# 33                                     PC-WHOLESALE 2020-10-05               9
# 34  PC-Super Market (MT in GT & Departmental Store) 2020-10-05              18
# 35  PC-Super Market (MT in GT & Departmental Store) 2020-10-05              18
# 36                         PC-KIRANA/GENERAL STORES 2020-10-05               1
# 37                         PC-KIRANA/GENERAL STORES 2020-10-05               2
# 38                         PC-KIRANA/GENERAL STORES 2020-10-05               1
# 39                                     PC-WHOLESALE 2020-10-05               9
# 40                                     PC-WHOLESALE 2020-10-05              18
# 41                                     PC-WHOLESALE 2020-10-05             129
# 42                                     PC-WHOLESALE 2020-10-05             129

# %% [markdown]
# ### Case 2: Without repetitions

# %%
def randompickAM_norep():
    result = randompick()
    result = result.merge(rtr_master,on='RtrCode')    
    final_r = result.drop_duplicates().reset_index(drop=True)
    index = final_r.index
    number_of_rows = len(index)
    print(number_of_rows)
    return(final_r)

""""    if (number_of_rows==pick):
        print('Selected')
        return(final_r)
    else:
        print('Try again') """
# Out:
# '"    if (number_of_rows==pick):\n        print(\'Selected\')\n        return(final_r)\n    else:\n        print(\'Try again\') '

# %%
randompickAM_norep()
# Out:
# 17
#                                        RtrCode        AMName  \
# 0                          S100000021550647196      BALAJI S
# 1                          S100000041550905617      BALAJI S
# 2                          S100000161550644936      BALAJI S
# 3                          S100000191551091753      BALAJI S
# 4                          S100000261551092772      BALAJI S
# 5                          S100000281550477351      BALAJI S
# 6                          S100000401550734471      BALAJI S
# 7                          S100000921551687342      BALAJI S
# 8                          S100000931551081127      BALAJI S
# 9   GT0100020035390002003539-SLM00241597645899     SAFIULLAH
# 10                         S100000591552984465     SAFIULLAH
# 11                         S100000661550836269     SAFIULLAH
# 12                         S100000701552040542     SAFIULLAH
# 13                   TNJTR006-SLM0011552299052     SAFIULLAH
# 14   GT0100020001530002000153-SLM0011560406478  SYED IBRAHIM
# 15   GT0100020001780002000178-SLM0041554711729  SYED IBRAHIM
# 16   GT0100020000890002000089-SLM0011559377878    V BHARATHI
#
#                      RtrName                                      RtrGroupCde  \
# 0   SRI MURUGAN SUPER MARKET  PC-Super Market (MT in GT & Departmental Store)
# 1             AKSHYA TRADERS                                     PC-WHOLESALE
# 2      THILAGAM SUPER MARKET  PC-Super Market (MT in GT & Departmental Store)
# 3               G.v traders                                      PC-WHOLESALE
# 4          NEW BALAJI STORE.                                     PC-WHOLESALE
# 5       THANGAPANDIAN  STORE                         PC-KIRANA/GENERAL STORES
# 6             National Store                                     PC-WHOLESALE
# 7      FATHIMA MALIGAI STORE                                     PC-WHOLESALE
# 8           SAIYED ARABHADH                          PC-KIRANA/GENERAL STORES
# 9                  A.N STORE                                     PC-WHOLESALE
# 10               Matha store                         PC-KIRANA/GENERAL STORES
# 11             SANJAY STORES                                     PC-WHOLESALE
# 12             Anitha stores                                     PC-WHOLESALE
# 13          NEW NELLAI STORR                         PC-KIRANA/GENERAL STORES
# 14           BILLAL MALIGAI                          PC-KIRANA/GENERAL STORES
# 15       APPLE SHOPPING MALL  PC-Super Market (MT in GT & Departmental Store)
# 16           m.h yosuf store                                     PC-WHOLESALE
#
#     PolypouchCount
# 0               18
# 1               45
# 2                1
# 3               90
# 4                9
# 5                1
# 6                9
# 7                1
# 8               27
# 9                1
# 10               1
# 11               9
# 12               9
# 13               1
# 14               1
# 15              18
# 16             129

# %% [markdown]
# ### Case 3: Without repetitions - Unique & number = pick

# %%
def randompickAM_norep_pick():
    result = randompick()
    result = result.merge(rtr_master,on='RtrCode')    
    final_r = result.drop_duplicates().reset_index(drop=True)
    index = final_r.index
    number_of_rows = len(index)
    print(number_of_rows)
    print(final_r)

    if (number_of_rows==pick):
        print('Selected')
        return(final_r)
    else:
        print('Try again')

# %%
randompickAM_norep_pick()
# Out:
# 18
#                                       RtrCode        AMName  \
# 0                         S100000021550647196      BALAJI S
# 1                         S100000041550905617      BALAJI S
# 2                         S100000151551252740      BALAJI S
# 3                         S100000161563351070      BALAJI S
# 4                         S100000191551091753      BALAJI S
# 5                         S100000401550565136      BALAJI S
# 6                         S100000431551076560      BALAJI S
# 7                         S100000431551682220      BALAJI S
# 8                         S100000931551081127      BALAJI S
# 9                   TNSSR009-SLM0011550908876      BALAJI S
# 10  GT0100020001120002000112-SLM0021572506614     SAFIULLAH
# 11                        S100000581597045306     SAFIULLAH
# 12                        S100000701552040542     SAFIULLAH
# 13                  TNJTR006-SLM0021552892243     SAFIULLAH
# 14  GT0100020001590002000159-SLM0021596182268  SYED IBRAHIM
# 15  GT0100020001640002000164-SLM0011573026022  SYED IBRAHIM
# 16                  TNPKS002-SLM0011553581012  SYED IBRAHIM
# 17  GT0100020000890002000089-SLM0011559377878    V BHARATHI
#
#                         RtrName  \
# 0      SRI MURUGAN SUPER MARKET
# 1                AKSHYA TRADERS
# 2                   R.C.TRADERS
# 3         SRI THIRUPTHI TRADERS
# 4                  G.v traders
# 5                 Mohammed zain
# 6               SRI KANNA STORE
# 7                  MADHAN STORE
# 8              SAIYED ARABHADH
# 9   Murugan Stores Super Market
# 10             NAT JI MARKETING
# 11                     Kr store
# 12                Anitha stores
# 13         PASUMI SUPER MARKET
# 14     SRI KRISHNA SUPER MARKET
# 15              S.R VETRI STORE
# 16               ARUNA AGENCIES
# 17              m.h yosuf store
#
#                                         RtrGroupCde  PolypouchCount
# 0   PC-Super Market (MT in GT & Departmental Store)              18
# 1                                      PC-WHOLESALE              45
# 2                                      PC-WHOLESALE              18
# 3                                      PC-WHOLESALE               9
# 4                                      PC-WHOLESALE              90
# 5                                      PC-WHOLESALE               9
# 6                          PC-KIRANA/GENERAL STORES               5
# 7                          PC-KIRANA/GENERAL STORES               1
# 8                          PC-KIRANA/GENERAL STORES              27
# 9   PC-Super Market (MT in GT & Departmental Store)              18
# 10                                     PC-WHOLESALE               9
# 11                         AB-KIRANA/GENERAL STORES               1
# 12                                     PC-WHOLESALE               9
# 13  PC-Super Market (MT in GT & Departmental Store)               2
# 14                                           PC-PAN               9
# 15                                     PC-WHOLESALE               9
# 16                                     PC-WHOLESALE              18
# 17                                     PC-WHOLESALE             129
# Try again

# %% [markdown]
# ## Function

# %%
## Import data
Query = 'select * from v_PC_MeeraRetailerCampaign' 
data = azsql.callstatement(Query)

# Data only for Latest date
data = data[data['InvDate'] == data['InvDate'].max()]

## Remove null - Retailers without AM
# Consider Data with AMName ( remove nulls)
data = data[data['AMName'].notnull()]

InvDate =  data['InvDate'].iloc[0]
InvDate = str(InvDate)[0:10]

## Retailer master
rtr_master = data[['RtrCode','RtrName','DistName','RtrGroupCde','InvDate','PolypouchCount']].drop_duplicates()
rtr_master['PolypouchCount'] = rtr_master['PolypouchCount'].astype(int)

AM_RTR_in = data.groupby('AMName')['RtrCode'].count().reset_index()

# Create text widget for output
output_slider_variable = widgets.Text()

# Define function to bind value of the input to the output variable 
def f(Lots):
    output_slider_variable.value = str(Lots)

print('Choose number of Lots')
# Create input slider with default value = 10  
interact(f, Lots=(10, 75, 1))

def picks(output_slider_variable,data):
    # Create and output new int variable with value of slider
    new_variable = int(output_slider_variable.value)

    ## Choose number of retailers to choose
    ## Weightage for AM
    # Percentage of Retailers across AM-Wise
    TotalRtrCount = data['RtrCode'].count()
    AM_RTR_WGT = data.groupby('AMName')['RtrCode'].count().reset_index()
    AM_RTR_WGT['WGT%'] = np.ceil(AM_RTR_WGT['RtrCode']/TotalRtrCount * new_variable)

    ## Split dataframe on AM's
    # Select required rows
    data1 = data[['ZM','AMName','RtrCode','RtrName','TotalQty','PolypouchCount']]
    data2 = [rows for _, rows in data1.groupby('AMName')]
    return data2,AM_RTR_WGT
    
## Function to generate random Rtr's with AM weightage
def randomRtrAmWise(i):
    data3,AM_RTR_WGT = picks(output_slider_variable,data)
    # Retailer name
    a = data3[i]['RtrCode'].tolist()

    # Polypouch count as weight
    ppc = data3[i]['PolypouchCount'].tolist() 

    c=int(AM_RTR_WGT['WGT%'][i])
    #random.shuffle(a)
    l = random.choices(a, weights=ppc, k=c)
    l.sort()
    df_R = pd.DataFrame(l,columns = ['RtrCode'])
    df_R['AMName'] = AM_RTR_WGT['AMName'][i]
    return df_R
    
def randompick(AM_RTR_in):
    df_RtrRP = pd.DataFrame()
    for j in range(len( AM_RTR_in.index.tolist())):
        df = randomRtrAmWise(j)
        df_RtrRP = df_RtrRP.append(df)
    return df_RtrRP

def randompickAM(rtr_master,AM_RTR_in,InvDate):
    result = randompick(AM_RTR_in)
    result = result.merge(rtr_master,on='RtrCode')
    result = result.groupby('RtrCode').head(2).reset_index(drop=True) # Keep 1st two instances of duplicates
    index = result.index
    number_of_rows = len(index)
    print('Count of picked retailers: ',number_of_rows)
    display(result)
    return result,InvDate
    
button = Button(description='Pick')
out = Output()

def on_click(_):
    with out:
        clear_output(True)
        dr,InvDate1 = randompickAM(rtr_master,AM_RTR_in,InvDate)
        # Save results
        root = 'Intermediate_csv' 
        sheet = 'results_' + InvDate1 + '.csv' 
        file_name = os.path.join(root,sheet)
        print(file_name)
        dr.to_csv(file_name,index=False)
        
button.on_click(on_click)
VBox([button,out])

# %% [markdown]
# ### Read & join csv in same folder

# %%
a = os.getcwd()
path = a + '\\Outputs_csv'
path

all_files = glob.glob(path + "/*.csv")

all_files

li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)
    
df_concat = pd.concat(li, axis=0, ignore_index=True)

# Convert InvDate to Date format
df_concat['InvDate'] = pd.to_datetime(df_concat['InvDate'])

# %% [markdown]
# ### Filter data by instances occuring in last week

# %%
days=6 #Last 6 days from current date
cutoff_date = df_concat['InvDate'].max() - pd.Timedelta(days=days)
print(cutoff_date)

df1_concat = df_concat[df_concat['InvDate'] > cutoff_date]

# List of last 6 days unique retailers
rtr_last6days = df1_concat[['RtrCode','RtrName']].drop_duplicates()
rtr_last6days = rtr_last6days['RtrCode'].tolist()

# Filter retailer occuring in last 6 days
data_filtered = data[~data.RtrCode.isin(rtr_last6days)]
